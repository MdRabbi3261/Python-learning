# %%
inp=int(input("Enter a string: "))
if inp<0:
    print(("negative number"))
elif inp==0 :
    print("zero")
else :
    print("positive number")

# %% [markdown]
# loop in python

# %%
## Looping in Python
inp = int(input("Enter a number: "))
for i in range(1,11):
    print(str(i)+" * "+str(inp)+" = "+str(i*inp))
# Out:
# 1 * 5 = 5
# 2 * 5 = 10
# 3 * 5 = 15
# 4 * 5 = 20
# 5 * 5 = 25
# 6 * 5 = 30
# 7 * 5 = 35
# 8 * 5 = 40
# 9 * 5 = 45
# 10 * 5 = 50

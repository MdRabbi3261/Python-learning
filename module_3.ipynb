# %%
massage=""" p8e4wyt euwhrtfn
riuheriuhn
hgiurehtoi
hgiurehtoi"""
print(massage)
# Out:
#  p8e4wyt euwhrtfn
# riuheriuhn
# hgiurehtoi
# hgiurehtoi

# %% [markdown]
# Indexing

# %%
str="Hello world"
print(str[0])
# Out:
# H

# %% [markdown]
# slicing
# stringname[start,end,step]

# %%
massage=""" p8e4wyt euwhrtfn
riuheriuhn
hgiurehtoi
hgiurehtoi"""

firstmassage=massage[0:50:2]
print(firstmassage)
# Out:
#  84y uhtnrueih
# guetihirho

# %% [markdown]
# problem 4

# %%
def power(base,exponent=2):
    return base**exponent
inp=input("Enter the base: ").split()
if len(inp)==1:
    print(power(int(inp[0])))
else:
    print(power(int(inp[0]),int(inp[1])))
# Out:
# 1953125

# %% [markdown]
# problem 5

# %%
numbers=[1,2,3,4,5,6]
even_numbers=list(filter(lambda x:(x%2==0),numbers))
squared_numbers=list(map(lambda x:(x**2),even_numbers))
print(squared_numbers)
# Out:
# [4, 16, 36]

# %% [markdown]
# problem 3

# %%
import pandas as pd
df=pd.DataFrame({'temperature()':[1,2,3,4]})
df['temperature()']=df['temperature()'].apply(lambda x:(x**2))
print(df)

# %% [markdown]
# problem 2

# %%
def batch_generator(data,batch_size):
    for i in range(0,len(data),batch_size):
        yield data[i:i+batch_size]
data=[1,2,3,4,5,6,7,8]
batch_size=3

for batch in batch_generator(data,batch_size):
    print(batch)

# %% [markdown]
# problem 1

# %%
def fullname(name,age):
    print(f"My name is {name} and I am {age} years old")
na=input("Enter your name: ")
nae=na.split()
name=nae[0]
age=int(nae[1])
fullname(name,age)

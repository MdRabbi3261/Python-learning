# %%
with open("D:/rabbi/PHITRON ML/sample.txt", "r") as file:
    content =file.readlines()
    print(content)
print(file.closed)
# Out:
# ['rabbi hgireg']
# True

# %%
file = open("D:/rabbi/PHITRON ML/sample.txt", "r")
content =file.readlines()
print(content)

file.close()
print(file.closed)
# Out:
# ['rabbi hgireg']
# True

# %%
file = open("D:/rabbi/PHITRON ML/sample.txt", "r")
content =file.read()
print(content)
file.close()
print(file.closed)
# Out:
# rabbi hgireg
# True

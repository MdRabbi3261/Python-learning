# %%
print("hello world")
# Out:
# hello world

# %%
num=2515
st="ieurth"
print(num)
print(st)
# Out:
# 2515
# ieurth

# %%
age=22
cgp=3.50
text="ehh"
print(type(age),type(cgp),type(text))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
name=input("Enter your name: ")
print(name)
# Out:
# trfuiefn

# %%
age=input("Enter your age :")
age=int(age)
print(age)
# Out:
# 5

# %%
x=5;y=3
div=round(x/3,3)
print(div)
# Out:
# 1.667

# %%
inp=input("Enter your number :")
number=inp.split()
x=int(number[0])
y=int(number[1])

lastdigitof_x=x%11
lastdigitof_y=y%11
sum=lastdigitof_x+lastdigitof_y
print(sum)
# Out:
# 7
